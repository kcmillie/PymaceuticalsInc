# %%
# Your objective is to analyze the data to show how four treatments (Capomulin, Infubinol, Ketapril, and Placebo) compare
#Creating a scatter plot that shows how the tumor volume changes over time for each treatment.
#Creating a scatter plot that shows how the number of metastatic (cancer spreading) sites changes over time for each treatment.
#Creating a scatter plot that shows the number of mice still alive through the course of treatment (Survival Rate)
#Creating a bar graph that compares the total % tumor volume change for each drug across the full 45 days.

# %%
# %matplotlib notebook

# %%
#Import libraries
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data_csv = "Resources/clinicaltrial_data.csv"
mouse_csv = "Resources/mouse_drug_data.csv"

# %%
data_df = pd.read_csv(data_csv)
mouse_df = pd.read_csv(mouse_csv)

# %%
#verifying data was read in correctly
data_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     b128          0                45.0                 0
# 1     f932          0                45.0                 0
# 2     g107          0                45.0                 0
# 3     a457          0                45.0                 0
# 4     c819          0                45.0                 0

# %%
#verifying data was read in correctly
mouse_df.head()
# Out:
#   Mouse ID      Drug
# 0     f234  Stelasyn
# 1     x402  Stelasyn
# 2     a492  Stelasyn
# 3     w540  Stelasyn
# 4     v764  Stelasyn

# %%
# make one big table & check to see if there are errors
bigtable_df = pd.merge(data_df, mouse_df, on='Mouse ID')

#count how many 
bigtable_df['Drug'].value_counts()
# Out:
# Capomulin    230
# Ramicane     228
# Stelasyn     194
# Ketapril     188
# Naftisol     186
# Zoniferol    182
# Placebo      181
# Ceftamin     178
# Infubinol    178
# Propriva     161
# Name: Drug, dtype: int64

# %%
new_bigtable_df = bigtable_df.set_index("Drug")
new_bigtable_df.head(20)
# Out:
#           Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# Drug
# Capomulin     b128          0           45.000000                 0
# Capomulin     b128          5           45.651331                 0
# Capomulin     b128         10           43.270852                 0
# Capomulin     b128         15           43.784893                 0
# Capomulin     b128         20           42.731552                 0
# Capomulin     b128         25           43.262145                 1
# Capomulin     b128         30           40.605335                 1
# Capomulin     b128         35           37.967644                 1
# Capomulin     b128         40           38.379726                 2
# Capomulin     b128         45           38.982878                 2
# Ketapril      f932          0           45.000000                 0
# Ketapril      g107          0           45.000000                 0
# Ketapril      g107          5           48.791665                 0
# ...

# %%
Capomulin_df = new_bigtable_df.loc['Capomulin',['Mouse ID', 'Timepoint', 'Tumor Volume (mm3)']]
#if mouseID(n) == mouseID(n+1), then tumorchange(n) = tumorvolume(n+1)-tumorvolumen(n) and
#timediff(n) = timepoint(n+1) - timepoint(n)
#Capomulin_df['Time Change'] = np.where(Capomulin_df['Mouse ID'] == Capomulin_df['Mouse ID'].shift(1),
#                                       (Capomulin_df['Timepoint'] - Capomulin_df['Timepoint'].shift(1)), 0)
#Capomulin_df['Volume Change'] = np.where(Capomulin_df['Mouse ID'] == Capomulin_df['Mouse ID'].shift(1),
#                                       (Capomulin_df['Tumor Volume (mm3)'] - Capomulin_df['Tumor Volume (mm3)'].shift(1)), 0)
for index in Capomulin_df.index:
    if Capomulin
Capomulin_df.head(25)
# Out:
#           Mouse ID  Timepoint  Tumor Volume (mm3)  Time Change  Volume Change
# Drug
# Capomulin     b128          0           45.000000          0.0       0.000000
# Capomulin     b128          5           45.651331          5.0       0.651331
# Capomulin     b128         10           43.270852          5.0      -2.380479
# Capomulin     b128         15           43.784893          5.0       0.514042
# Capomulin     b128         20           42.731552          5.0      -1.053341
# Capomulin     b128         25           43.262145          5.0       0.530593
# Capomulin     b128         30           40.605335          5.0      -2.656810
# Capomulin     b128         35           37.967644          5.0      -2.637690
# Capomulin     b128         40           38.379726          5.0       0.412082
# Capomulin     b128         45           38.982878          5.0       0.603152
# Capomulin     j246          0           45.000000          0.0       0.000000
# ...

# %%
#Creating a scatter plot that shows how the tumor volume changes over time for each treatment.
